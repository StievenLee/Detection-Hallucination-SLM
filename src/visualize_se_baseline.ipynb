# %%
import pandas as pd
import numpy as np

# %%
result_tinyllama = pd.read_csv('../results/metrics/tinyllama/se_auroc_summary.csv')
result_tinyllama
# Out:
#                                 model    dataset language  n_questions   M  \
# 0  TinyLlama/TinyLlama-1.1B-Chat-v1.0  trivia_qa       en          100  10
# 1  TinyLlama/TinyLlama-1.1B-Chat-v1.0     bioasq       en          100  10
# 2  TinyLlama/TinyLlama-1.1B-Chat-v1.0      facqa       id          100  10
# 3  TinyLlama/TinyLlama-1.1B-Chat-v1.0      wrete       id          100  10
#
#    temperature   auroc   aurac  best_threshold  accuracy  ...  \
# 0          0.5  0.7807  0.2502             NaN      0.24  ...
# 1          0.5  0.5971  0.0535             NaN      0.08  ...
# 2          0.5  0.5434  0.1765             NaN      0.22  ...
# 3          0.5  0.4130  0.1300             NaN      0.23  ...
#
#    similarity_calls_total  avg_latency_s  throughput_tok_s  peak_ram_mb  \
# 0                    4500         203.64              1.73       2731.1
# 1                    4500         232.93              1.35       3172.4
# 2                    4500         185.71              1.75       2980.0
# 3                    4500         303.32              1.13       2117.2
#
#    f1_threshold  max_tokens  load_time_s  model_size_mb  ram_after_load_mb  \
# 0           0.5          30        4.412         2098.2             2529.5
# 1           0.5          30        5.954         2098.2             3172.4
# 2           0.5          30        4.438         2098.2             1876.1
# 3           0.5          30        7.841         2098.2              870.9
#
#    ram_available_mb
# 0            2407.5
# 1            2750.3
# 2            1557.3
# 3            2173.3
#
# [4 rows x 24 columns]

# %%
result_phi = pd.read_csv('../results/metrics/phi/se_auroc_summary.csv')
result_phi2 = pd.read_csv('../results/metrics/phi/se_auroc_summary(2).csv')
result_phi
# Out:
#                model    dataset language  n_questions   M  temperature  \
# 0  microsoft/phi-1_5  trivia_qa       en          100  10          0.5
# 1  microsoft/phi-1_5     bioasq       en          100  10          0.5
#
#     auroc   aurac  best_threshold  accuracy  ...  similarity_calls_total  \
# 0  0.7235  0.1467             NaN      0.08  ...                    4500
# 1  0.5247  0.0372             NaN      0.04  ...                    4500
#
#    avg_latency_s  throughput_tok_s  peak_ram_mb  f1_threshold  max_tokens  \
# 0         295.05              1.13       1447.2           0.5          30
# 1         155.36              2.24       3246.7           0.5          30
#
#    load_time_s  model_size_mb  ram_after_load_mb  ram_available_mb
# 0        2.218         2705.1              751.2            1348.9
# 1        1.617         2705.1             1413.6            2526.0
#
# [2 rows x 24 columns]

# %%
result_phi2
# Out:
#                model dataset language  n_questions   M  temperature   auroc  \
# 0  microsoft/phi-1_5   facqa       id          100  10          0.5  0.6375
# 1  microsoft/phi-1_5   wrete       id          100  10          0.5  0.5000
#
#     aurac  best_threshold  accuracy  ...  similarity_calls_total  \
# 0  0.0331             NaN      0.03  ...                    4500
# 1  0.1396             NaN      0.15  ...                    4500
#
#    avg_latency_s  throughput_tok_s  peak_ram_mb  f1_threshold  max_tokens  \
# 0         138.44              2.45       3438.9           0.5          30
# 1         134.29              2.54       3463.8           0.5          30
#
#    load_time_s  model_size_mb  ram_after_load_mb  ram_available_mb
# 0        1.904         2705.1              753.7            3190.3
# 1        1.526         2705.1              907.6            4926.1
#
# [2 rows x 24 columns]

# %%
result_qwen = pd.read_csv('../results/metrics/qwen/se_auroc_summary.csv')
result_qwen
# Out:
#                     model    dataset language  n_questions   M  temperature  \
# 0  Qwen/Qwen1.5-1.8B-Chat  trivia_qa       en          100  10          0.5
# 1  Qwen/Qwen1.5-1.8B-Chat     bioasq       en          100  10          0.5
# 2  Qwen/Qwen1.5-1.8B-Chat      facqa       id          100  10          0.5
# 3  Qwen/Qwen1.5-1.8B-Chat      wrete       id          100  10          0.5
#
#     auroc   aurac  best_threshold  accuracy  ...  similarity_calls_total  \
# 0  0.8546  0.1912             NaN      0.13  ...                    4500
# 1  0.4260  0.0142             NaN      0.02  ...                    4500
# 2  0.6072  0.2578             NaN      0.49  ...                    4500
# 3  0.5023  0.5964          1.2675      0.68  ...                    4500
#
#    avg_latency_s  throughput_tok_s  peak_ram_mb  f1_threshold  max_tokens  \
# 0         238.12              0.52       2640.3           0.5          30
# 1          94.20              2.25       5040.3           0.5          30
# 2         196.37              1.33       4344.9           0.5          30
# 3         263.23              1.09       3619.5           0.5          30
#
#    load_time_s  model_size_mb  ram_after_load_mb  ram_available_mb
# 0        8.469         3503.5             1943.0            3260.1
# 1        4.750         3503.5             5021.2            3804.1
# 2        6.664         3503.5             4210.4            3679.1
# 3        6.073         3503.5             2771.7            3761.5
#
# [4 rows x 24 columns]
